# %% [markdown]
# https://docs.crewai.com/en/learn/sequential-process

# %%
pip install crewai
# Out:
# Collecting crewai
#   Using cached crewai-0.140.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.4.4)
# Collecting blinker>=1.9.0 (from crewai)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: chromadb>=0.5.23 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.0.13)
# Requirement already satisfied: click>=8.1.7 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (8.1.7)
# Collecting instructor>=1.3.3 (from crewai)
#   Using cached instructor-1.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair==0.25.2 (from crewai)
#   Using cached json_repair-0.25.2-py3-none-any.whl.metadata (7.9 kB)
# Collecting json5>=0.10.0 (from crewai)
#   Using cached json5-0.12.0-py3-none-any.whl.metadata (36 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.72.6 (from crewai)
#   Using cached litellm-1.72.6-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: onnxruntime==1.22.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.22.0)
# Requirement already satisfied: openai>=1.13.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.92.2)
# Requirement already satisfied: openpyxl>=3.1.5 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.30.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.34.1)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.30.0 (from crewai)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.34.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.30.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (1.34.1)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Using cached pdfplumber-0.11.7-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: pydantic>=2.4.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (2.11.7)
# Collecting pyjwt>=2.9.0 (from crewai)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting python-dotenv>=1.0.0 (from crewai)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting pyvis>=0.3.2 (from crewai)
#   Using cached pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: tokenizers>=0.20.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from crewai) (0.21.2)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Using cached tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Using cached tomli-2.2.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Using cached uv-0.7.19-py3-none-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: aiohttp in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (3.10.5)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (0.27.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (7.0.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (3.1.4)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from litellm==1.72.6->crewai) (0.9.0)
# Requirement already satisfied: coloredlogs in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (1.26.4)
# Requirement already satisfied: packaging in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (24.1)
# Requirement already satisfied: protobuf in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (5.29.5)
# Requirement already satisfied: sympy in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from onnxruntime==1.22.0->crewai) (1.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.72.6->crewai) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.72.6->crewai) (0.10.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pydantic>=2.4.2->crewai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pydantic>=2.4.2->crewai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pydantic>=2.4.2->crewai) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pydantic>=2.4.2->crewai) (0.4.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (5.4.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (1.72.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from chromadb>=0.5.23->crewai) (13.7.1)
# Requirement already satisfied: pyproject_hooks in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: colorama in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (0.4.6)
# Requirement already satisfied: anyio in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (1.0.2)
# Requirement already satisfied: idna in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (3.7)
# Requirement already satisfied: sniffio in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpx>=0.23.0->litellm==1.72.6->crewai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.72.6->crewai) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from importlib-metadata>=6.8.0->litellm==1.72.6->crewai) (3.17.0)
# Collecting docstring-parser<1.0,>=0.16 (from instructor>=1.3.3->crewai)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: jiter<0.11,>=0.6.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from instructor>=1.3.3->crewai) (0.10.0)
# Collecting mkdocs-material>=9.5.49 (from instructor>=1.3.3->crewai)
#   Using cached mkdocs_material-9.6.15-py3-none-any.whl.metadata (19 kB)
# Collecting mkdocs>=1.6.1 (from instructor>=1.3.3->crewai)
#   Using cached mkdocs-1.6.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting pre-commit>=4.2.0 (from instructor>=1.3.3->crewai)
#   Using cached pre_commit-4.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from instructor>=1.3.3->crewai) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from aiohttp->litellm==1.72.6->crewai) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from aiohttp->litellm==1.72.6->crewai) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from aiohttp->litellm==1.72.6->crewai) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from aiohttp->litellm==1.72.6->crewai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from aiohttp->litellm==1.72.6->crewai) (1.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->instructor>=1.3.3->crewai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from requests<3.0.0,>=2.32.3->instructor>=1.3.3->crewai) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (2.15.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: six>=1.9.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.8)
# Requirement already satisfied: mdurl~=0.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.0)
# Collecting ghp-import>=1.0 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached ghp_import-2.1.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: markdown>=3.3.6 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (3.4.1)
# Collecting mergedeep>=1.3.4 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting mkdocs-get-deps>=0.2.0 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached mkdocs_get_deps-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathspec>=0.11.1 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml-env-tag>=0.1 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached pyyaml_env_tag-1.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: watchdog>=2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from mkdocs>=1.6.1->instructor>=1.3.3->crewai) (4.0.1)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from mkdocs-get-deps>=0.2.0->mkdocs>=1.6.1->instructor>=1.3.3->crewai) (3.10.0)
# Requirement already satisfied: babel~=2.10 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (2.11.0)
# Collecting backrefs~=5.7.post1 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Using cached backrefs-5.9-py312-none-any.whl.metadata (3.2 kB)
# Collecting mkdocs-material-extensions~=1.3 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Using cached mkdocs_material_extensions-1.3.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting paginate~=0.5 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Using cached paginate-0.5.7-py2.py3-none-any.whl.metadata (11 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->chromadb>=0.5.23->crewai)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting pymdown-extensions~=10.2 (from mkdocs-material>=9.5.49->instructor>=1.3.3->crewai)
#   Using cached pymdown_extensions-10.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pytz>=2015.7 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from babel~=2.10->mkdocs-material>=9.5.49->instructor>=1.3.3->crewai) (2024.1)
# Collecting markdown>=3.3.6 (from mkdocs>=1.6.1->instructor>=1.3.3->crewai)
#   Using cached markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: et-xmlfile in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from openpyxl>=3.1.5->crewai) (1.1.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.23->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from opentelemetry-sdk>=1.30.0->crewai) (0.55b1)
# Collecting pdfminer.six==20250506 (from pdfplumber>=0.11.4->crewai)
#   Using cached pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pdfplumber>=0.11.4->crewai) (10.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber>=0.11.4->crewai) (2.21)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Collecting cfgv>=2.0.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Using cached cfgv-3.4.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Collecting identify>=1.0.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Using cached identify-2.6.12-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Using cached nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Collecting virtualenv>=20.10.0 (from pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Using cached virtualenv-20.31.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pyvis>=0.3.2->crewai) (8.27.0)
# Collecting jsonpickle>=1.4.1 (from pyvis>=0.3.2->crewai)
#   Using cached jsonpickle-4.1.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: networkx>=1.11 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from pyvis>=0.3.2->crewai) (3.3)
# Requirement already satisfied: decorator in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.43)
# Requirement already satisfied: stack-data in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from tokenizers>=0.20.3->crewai) (0.33.1)
# Requirement already satisfied: filelock in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.20.3->crewai) (2024.6.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (15.0.1)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=4.2.0->instructor>=1.3.3->crewai)
#   Using cached distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from coloredlogs->onnxruntime==1.22.0->crewai) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime==1.22.0->crewai) (3.5.4)
# Requirement already satisfied: executing in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\adity\anaconda3\real_anaconda\lib\site-packages (from sympy->onnxruntime==1.22.0->crewai) (1.3.0)
# Using cached crewai-0.140.0-py3-none-any.whl (335 kB)
# Using cached json_repair-0.25.2-py3-none-any.whl (12 kB)
# Using cached litellm-1.72.6-py3-none-any.whl (8.3 MB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached instructor-1.9.0-py3-none-any.whl (94 kB)
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Using cached json5-0.12.0-py3-none-any.whl (36 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Using cached mkdocs-1.6.1-py3-none-any.whl (3.9 MB)
# Using cached ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Using cached mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Using cached mkdocs_get_deps-0.2.0-py3-none-any.whl (9.5 kB)
# Using cached mkdocs_material-9.6.15-py3-none-any.whl (8.7 MB)
# Using cached backrefs-5.9-py312-none-any.whl (397 kB)
# Using cached mkdocs_material_extensions-1.3.1-py3-none-any.whl (8.7 kB)
# Using cached paginate-0.5.7-py2.py3-none-any.whl (13 kB)
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 419.4 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 419.4 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 419.4 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 419.4 kB/s eta 0:00:02
#    ------------------------- -------------- 0.8/1.2 MB 368.7 kB/s eta 0:00:02
#    ------------------------- -------------- 0.8/1.2 MB 368.7 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.0/1.2 MB 437.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 474.2 kB/s eta 0:00:00
# Using cached pymdown_extensions-10.16-py3-none-any.whl (266 kB)
# Using cached markdown-3.8.2-py3-none-any.whl (106 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.34.1-py3-none-any.whl (17 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached pdfplumber-0.11.7-py3-none-any.whl (60 kB)
# Using cached pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
# Using cached pre_commit-4.2.0-py2.py3-none-any.whl (220 kB)
# Using cached cfgv-3.4.0-py2.py3-none-any.whl (7.2 kB)
# Using cached identify-2.6.12-py2.py3-none-any.whl (99 kB)
# Using cached nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached pyvis-0.3.2-py3-none-any.whl (756 kB)
# Using cached jsonpickle-4.1.1-py3-none-any.whl (47 kB)
# Using cached pyyaml_env_tag-1.1-py3-none-any.whl (4.7 kB)
# Using cached tomli-2.2.1-cp312-cp312-win_amd64.whl (109 kB)
# Using cached tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Using cached uv-0.7.19-py3-none-win_amd64.whl (19.3 MB)
# Using cached virtualenv-20.31.2-py3-none-any.whl (6.1 MB)
# Using cached distlib-0.3.9-py2.py3-none-any.whl (468 kB)
# Installing collected packages: paginate, distlib, virtualenv, uv, tomli-w, tomli, pyyaml-env-tag, python-dotenv, pypdfium2, pyjwt, pygments, pathspec, nodeenv, mkdocs-material-extensions, mergedeep, markdown, jsonref, jsonpickle, json5, json-repair, identify, docstring-parser, cfgv, blinker, backrefs, pymdown-extensions, pre-commit, mkdocs-get-deps, ghp-import, pdfminer.six, mkdocs, pyvis, pdfplumber, mkdocs-material, litellm, opentelemetry-exporter-otlp-proto-http, instructor, crewai
#
#    - --------------------------------------  1/38 [distlib]
#    -- -------------------------------------  2/38 [virtualenv]
#    -- -------------------------------------  2/38 [virtualenv]
#    -- -------------------------------------  2/38 [virtualenv]
#    --- ------------------------------------  3/38 [uv]
#    --- ------------------------------------  3/38 [uv]
#   Attempting uninstall: tomli
#    --- ------------------------------------  3/38 [uv]
#     Found existing installation: tomli 2.0.1
#    --- ------------------------------------  3/38 [uv]
#     Uninstalling tomli-2.0.1:
#    --- ------------------------------------  3/38 [uv]
#       Successfully uninstalled tomli-2.0.1
#    --- ------------------------------------  3/38 [uv]
#    ----- ----------------------------------  5/38 [tomli]
#   Attempting uninstall: python-dotenv
#    ----- ----------------------------------  5/38 [tomli]
#     Found existing installation: python-dotenv 0.21.0
#    ----- ----------------------------------  5/38 [tomli]
#     Uninstalling python-dotenv-0.21.0:
#    ----- ----------------------------------  5/38 [tomli]
#       Successfully uninstalled python-dotenv-0.21.0
#    ----- ----------------------------------  5/38 [tomli]
#    ------- --------------------------------  7/38 [python-dotenv]
#    -------- -------------------------------  8/38 [pypdfium2]
#    -------- -------------------------------  8/38 [pypdfium2]
#   Attempting uninstall: pyjwt
#    -------- -------------------------------  8/38 [pypdfium2]
#     Found existing installation: PyJWT 2.8.0
#    -------- -------------------------------  8/38 [pypdfium2]
#     Uninstalling PyJWT-2.8.0:
#    -------- -------------------------------  8/38 [pypdfium2]
#       Successfully uninstalled PyJWT-2.8.0
#    -------- -------------------------------  8/38 [pypdfium2]
#    --------- ------------------------------  9/38 [pyjwt]
#   Attempting uninstall: pygments
#    --------- ------------------------------  9/38 [pyjwt]
#     Found existing installation: Pygments 2.15.1
#    --------- ------------------------------  9/38 [pyjwt]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#     Uninstalling Pygments-2.15.1:
#    ---------- ----------------------------- 10/38 [pygments]
#       Successfully uninstalled Pygments-2.15.1
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#    ---------- ----------------------------- 10/38 [pygments]
#   Attempting uninstall: pathspec
#    ---------- ----------------------------- 10/38 [pygments]
#     Found existing installation: pathspec 0.10.3
#    ---------- ----------------------------- 10/38 [pygments]
#     Uninstalling pathspec-0.10.3:
#    ---------- ----------------------------- 10/38 [pygments]
#       Successfully uninstalled pathspec-0.10.3
#    ---------- ----------------------------- 10/38 [pygments]
#    ----------- ---------------------------- 11/38 [pathspec]
#   Attempting uninstall: markdown
#    ----------- ---------------------------- 11/38 [pathspec]
#     Found existing installation: Markdown 3.4.1
#    ----------- ---------------------------- 11/38 [pathspec]
#     Uninstalling Markdown-3.4.1:
#    ----------- ---------------------------- 11/38 [pathspec]
#       Successfully uninstalled Markdown-3.4.1
#    ----------- ---------------------------- 11/38 [pathspec]
#    --------------- ------------------------ 15/38 [markdown]
#    --------------- ------------------------ 15/38 [markdown]
#    ----------------- ---------------------- 17/38 [jsonpickle]
#   Attempting uninstall: json5
#    ----------------- ---------------------- 17/38 [jsonpickle]
#     Found existing installation: json5 0.9.6
#    ----------------- ---------------------- 17/38 [jsonpickle]
#     Uninstalling json5-0.9.6:
#    ----------------- ---------------------- 17/38 [jsonpickle]
#       Successfully uninstalled json5-0.9.6
#    ----------------- ---------------------- 17/38 [jsonpickle]
#    ------------------ --------------------- 18/38 [json5]
#    --------------------- ------------------ 20/38 [identify]
#    ---------------------- ----------------- 21/38 [docstring-parser]
#   Attempting uninstall: blinker
#    ---------------------- ----------------- 21/38 [docstring-parser]
#     Found existing installation: blinker 1.6.2
#    ---------------------- ----------------- 21/38 [docstring-parser]
#     Uninstalling blinker-1.6.2:
#    ---------------------- ----------------- 21/38 [docstring-parser]
#       Successfully uninstalled blinker-1.6.2
#    ---------------------- ----------------- 21/38 [docstring-parser]
#    ------------------------- -------------- 24/38 [backrefs]
#    ------------------------- -------------- 24/38 [backrefs]
#    ------------------------- -------------- 24/38 [backrefs]
#    -------------------------- ------------- 25/38 [pymdown-extensions]
#    -------------------------- ------------- 25/38 [pymdown-extensions]
#    -------------------------- ------------- 25/38 [pymdown-extensions]
#    --------------------------- ------------ 26/38 [pre-commit]
#    ---------------------------- ----------- 27/38 [mkdocs-get-deps]
#    ------------------------------ --------- 29/38 [pdfminer.six]
#    ------------------------------ --------- 29/38 [pdfminer.six]
#    ------------------------------- -------- 30/38 [mkdocs]
#    ------------------------------- -------- 30/38 [mkdocs]
#    ------------------------------- -------- 30/38 [mkdocs]
#    -------------------------------- ------- 31/38 [pyvis]
#    --------------------------------- ------ 32/38 [pdfplumber]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ---------------------------------- ----- 33/38 [mkdocs-material]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    ----------------------------------- ---- 34/38 [litellm]
#    -------------------------- -- 35/38 [opentelemetry-exporter-otlp-proto-http]
#    ------------------------------------- -- 36/38 [instructor]
#    ------------------------------------- -- 36/38 [instructor]
#    ------------------------------------- -- 36/38 [instructor]
#    ------------------------------------- -- 36/38 [instructor]
#    ------------------------------------- -- 36/38 [instructor]
#    ------------------------------------- -- 36/38 [instructor]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    -------------------------------------- - 37/38 [crewai]
#    ---------------------------------------- 38/38 [crewai]
#
# Successfully installed backrefs-5.9 blinker-1.9.0 cfgv-3.4.0 crewai-0.140.0 distlib-0.3.9 docstring-parser-0.16 ghp-import-2.1.0 identify-2.6.12 instructor-1.9.0 json-repair-0.25.2 json5-0.12.0 jsonpickle-4.1.1 jsonref-1.1.0 litellm-1.72.6 markdown-3.8.2 mergedeep-1.3.4 mkdocs-1.6.1 mkdocs-get-deps-0.2.0 mkdocs-material-9.6.15 mkdocs-material-extensions-1.3.1 nodeenv-1.9.1 opentelemetry-exporter-otlp-proto-http-1.34.1 paginate-0.5.7 pathspec-0.12.1 pdfminer.six-20250506 pdfplumber-0.11.7 pre-commit-4.2.0 pygments-2.19.2 pyjwt-2.10.1 pymdown-extensions-10.16 pypdfium2-4.30.1 python-dotenv-1.1.1 pyvis-0.3.2 pyyaml-env-tag-1.1 tomli-2.2.1 tomli-w-1.2.0 uv-0.7.19 virtualenv-20.31.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/cfgv/

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

# %%
llm  = ChatGroq(model="groq/llama-3.3-70b-versatile")

# %%
from crewai import Crew, Process, Agent, Task , TaskOutput, CrewOutput

## Define Agents

researcher = Agent(
    role = "Researcher",
    goal="Conduct Foundational Research",
    backstory="An experienced researcher with an passion for uncovering insights",
    llm=llm
)

analyst = Agent(
  role='Data Analyst',
  goal='Analyze research findings',
  backstory='A meticulous analyst with a knack for uncovering patterns',
  llm=llm
)

writer = Agent(
  role='Writer',
  goal='Draft the final report',
  backstory='A skilled writer with a talent for crafting compelling narratives',
  llm=llm
)

## Defining the tasks

research_task = Task(
    agent = researcher,
    description="Gather Relevant data on the topic",
    expected_output="Raw data"
)

analysis_task = Task(
    agent=analyst, 
    description='Analyze the data...', 
    expected_output='Data Insights'
)
writing_task = Task(
    agent=writer,
    description='Compose the report...',  
    expected_output='Final Report'
)

# Form the crew with a sequential process

report_crew = Crew(
    agents = [researcher,analyst,writer],
    tasks = [research_task,analysis_task,writing_task],
    process = Process.sequential  # P is capital in Process
)

## Execute the crew
result = report_crew.kickoff()

# %%
result
# Out:
# CrewOutput(raw='**Final Report: Comprehensive Analysis of Current Trends and Challenges**\n\n**Introduction**\n\nThis report provides an in-depth analysis of current trends, challenges, and opportunities across five critical areas: Climate Change, Artificial Intelligence, Renewable Energy, Cybersecurity, and Healthcare. The insights drawn from extensive data collection and analysis are intended to inform policy, business strategy, and individual actions to address global challenges and leverage emerging technologies and trends.\n\n**Topic 1: Climate Change**\n\nThe data on climate change paints a stark picture of the urgent need for global action. Key findings include:\n\n1. **Global Temperature Increase**: The global temperature has risen by 1.8 degrees Fahrenheit since 1880, indicating a significant and alarming trend.\n2. **Recent Temperature Records**: The past four years have been the hottest on record, highlighting the accelerating pace of global warming.\n3. **Carbon Dioxide Levels**: A 40% increase in carbon dioxide levels since the Industrial Revolution underscores the impact of human activities on the climate.\n4. **Sea Level Rise**: The 8-inch rise in sea levels over the past century and the loss of about 75% of Arctic ice thickness since the 1980s demonstrate the severe and tangible impacts of climate change.\n\nThese findings emphasize the critical need for immediate and sustained action to reduce greenhouse gas emissions and transition to renewable energy sources.\n\n**Topic 2: Artificial Intelligence**\n\nThe analysis of artificial intelligence (AI) trends reveals a rapidly expanding sector with significant implications for businesses and societies:\n\n1. **Market Growth**: The projected growth of the global AI market to $190 billion by 2025 indicates a rapid expansion of AI technologies across industries.\n2. **Business Adoption**: 61% of businesses have already implemented some form of AI, suggesting that AI is becoming a standard tool for competitiveness.\n3. **Applications of AI**: The predominant use of AI in customer service, sales, and marketing implies that businesses are leveraging AI for direct customer interaction and revenue generation.\n4. **Strategic Importance**: The belief by 80% of companies that AI will be a key factor in their success underscores the strategic importance of AI in business planning.\n5. **Key Technologies**: The focus on machine learning, natural language processing, and computer vision as the top AI technologies indicates where innovation and investment are concentrated.\n\nThese insights highlight the transformative potential of AI and the need for businesses to embrace AI to remain competitive.\n\n**Topic 3: Renewable Energy**\n\nThe data on renewable energy shows significant progress in the adoption of clean energy sources:\n\n1. **Global Electricity Generation**: Renewable energy accounts for 26% of global electricity generation, indicating a substantial shift towards cleaner energy.\n2. **Growth of Solar and Wind Energy**: The 22% growth of solar energy in the past year alone and the 15% increase in wind energy over the past five years highlight the rapid expansion of specific renewable energy technologies.\n3. **Hydroelectric Power**: Hydroelectric power being the largest source of renewable energy underscores the importance of traditional renewable sources.\n4. **Cost Decrease**: The 70% decrease in the cost of renewable energy over the past decade makes renewable energy more economically viable and competitive with fossil fuels.\n\nThese findings suggest that renewable energy is becoming an increasingly important part of the global energy mix, driven by technological advancements and economic viability.\n\n**Topic 4: Cybersecurity**\n\nThe analysis of cybersecurity trends reveals a growing threat with significant financial and operational implications:\n\n1. **Expected Cost of Cybercrime**: The expected cost of cybercrime reaching $6 trillion by 2025 emphasizes the gro ...

# %%
# Accessing the type-safe output

crew_output : CrewOutput = result.raw

# %%
crew_output
# Out:
# '**Final Report: Comprehensive Analysis of Current Trends and Challenges**\n\n**Introduction**\n\nThis report provides an in-depth analysis of current trends, challenges, and opportunities across five critical areas: Climate Change, Artificial Intelligence, Renewable Energy, Cybersecurity, and Healthcare. The insights drawn from extensive data collection and analysis are intended to inform policy, business strategy, and individual actions to address global challenges and leverage emerging technologies and trends.\n\n**Topic 1: Climate Change**\n\nThe data on climate change paints a stark picture of the urgent need for global action. Key findings include:\n\n1. **Global Temperature Increase**: The global temperature has risen by 1.8 degrees Fahrenheit since 1880, indicating a significant and alarming trend.\n2. **Recent Temperature Records**: The past four years have been the hottest on record, highlighting the accelerating pace of global warming.\n3. **Carbon Dioxide Levels**: A 40% increase in carbon dioxide levels since the Industrial Revolution underscores the impact of human activities on the climate.\n4. **Sea Level Rise**: The 8-inch rise in sea levels over the past century and the loss of about 75% of Arctic ice thickness since the 1980s demonstrate the severe and tangible impacts of climate change.\n\nThese findings emphasize the critical need for immediate and sustained action to reduce greenhouse gas emissions and transition to renewable energy sources.\n\n**Topic 2: Artificial Intelligence**\n\nThe analysis of artificial intelligence (AI) trends reveals a rapidly expanding sector with significant implications for businesses and societies:\n\n1. **Market Growth**: The projected growth of the global AI market to $190 billion by 2025 indicates a rapid expansion of AI technologies across industries.\n2. **Business Adoption**: 61% of businesses have already implemented some form of AI, suggesting that AI is becoming a standard tool for competitiveness.\n3. **Applications of AI**: The predominant use of AI in customer service, sales, and marketing implies that businesses are leveraging AI for direct customer interaction and revenue generation.\n4. **Strategic Importance**: The belief by 80% of companies that AI will be a key factor in their success underscores the strategic importance of AI in business planning.\n5. **Key Technologies**: The focus on machine learning, natural language processing, and computer vision as the top AI technologies indicates where innovation and investment are concentrated.\n\nThese insights highlight the transformative potential of AI and the need for businesses to embrace AI to remain competitive.\n\n**Topic 3: Renewable Energy**\n\nThe data on renewable energy shows significant progress in the adoption of clean energy sources:\n\n1. **Global Electricity Generation**: Renewable energy accounts for 26% of global electricity generation, indicating a substantial shift towards cleaner energy.\n2. **Growth of Solar and Wind Energy**: The 22% growth of solar energy in the past year alone and the 15% increase in wind energy over the past five years highlight the rapid expansion of specific renewable energy technologies.\n3. **Hydroelectric Power**: Hydroelectric power being the largest source of renewable energy underscores the importance of traditional renewable sources.\n4. **Cost Decrease**: The 70% decrease in the cost of renewable energy over the past decade makes renewable energy more economically viable and competitive with fossil fuels.\n\nThese findings suggest that renewable energy is becoming an increasingly important part of the global energy mix, driven by technological advancements and economic viability.\n\n**Topic 4: Cybersecurity**\n\nThe analysis of cybersecurity trends reveals a growing threat with significant financial and operational implications:\n\n1. **Expected Cost of Cybercrime**: The expected cost of cybercrime reaching $6 trillion by 2025 emphasizes the growing threat and ...

# %%
print(crew_output)
# Out:
# **Final Report: Comprehensive Analysis of Current Trends and Challenges**
#
# **Introduction**
#
# This report provides an in-depth analysis of current trends, challenges, and opportunities across five critical areas: Climate Change, Artificial Intelligence, Renewable Energy, Cybersecurity, and Healthcare. The insights drawn from extensive data collection and analysis are intended to inform policy, business strategy, and individual actions to address global challenges and leverage emerging technologies and trends.
#
# **Topic 1: Climate Change**
#
# The data on climate change paints a stark picture of the urgent need for global action. Key findings include:
#
# 1. **Global Temperature Increase**: The global temperature has risen by 1.8 degrees Fahrenheit since 1880, indicating a significant and alarming trend.
# 2. **Recent Temperature Records**: The past four years have been the hottest on record, highlighting the accelerating pace of global warming.
# 3. **Carbon Dioxide Levels**: A 40% increase in carbon dioxide levels since the Industrial Revolution underscores the impact of human activities on the climate.
# 4. **Sea Level Rise**: The 8-inch rise in sea levels over the past century and the loss of about 75% of Arctic ice thickness since the 1980s demonstrate the severe and tangible impacts of climate change.
#
# These findings emphasize the critical need for immediate and sustained action to reduce greenhouse gas emissions and transition to renewable energy sources.
#
# **Topic 2: Artificial Intelligence**
#
# The analysis of artificial intelligence (AI) trends reveals a rapidly expanding sector with significant implications for businesses and societies:
#
# 1. **Market Growth**: The projected growth of the global AI market to $190 billion by 2025 indicates a rapid expansion of AI technologies across industries.
# 2. **Business Adoption**: 61% of businesses have already implemented some form of AI, suggesting that AI is becoming a standard tool for competitiveness.
# 3. **Applications of AI**: The predominant use of AI in customer service, sales, and marketing implies that businesses are leveraging AI for direct customer interaction and revenue generation.
# 4. **Strategic Importance**: The belief by 80% of companies that AI will be a key factor in their success underscores the strategic importance of AI in business planning.
# 5. **Key Technologies**: The focus on machine learning, natural language processing, and computer vision as the top AI technologies indicates where innovation and investment are concentrated.
#
# These insights highlight the transformative potential of AI and the need for businesses to embrace AI to remain competitive.
#
# **Topic 3: Renewable Energy**
#
# The data on renewable energy shows significant progress in the adoption of clean energy sources:
#
# 1. **Global Electricity Generation**: Renewable energy accounts for 26% of global electricity generation, indicating a substantial shift towards cleaner energy.
# 2. **Growth of Solar and Wind Energy**: The 22% growth of solar energy in the past year alone and the 15% increase in wind energy over the past five years highlight the rapid expansion of specific renewable energy technologies.
# 3. **Hydroelectric Power**: Hydroelectric power being the largest source of renewable energy underscores the importance of traditional renewable sources.
# 4. **Cost Decrease**: The 70% decrease in the cost of renewable energy over the past decade makes renewable energy more economically viable and competitive with fossil fuels.
#
# These findings suggest that renewable energy is becoming an increasingly important part of the global energy mix, driven by technological advancements and economic viability.
#
# **Topic 4: Cybersecurity**
#
# The analysis of cybersecurity trends reveals a growing threat with significant financial and operational implications:
#
# 1. **Expected Cost of Cybercrime**: The expected cost of cybercrime reaching $6 trillion by 2025 emphasizes the growing threat and financial impact of cyberattacks.
# 2. **Incidence of Cyberattacks**: 64% of companies experiencing a cyberattack in the past year indicates a high incidence of cybercrime affecting businesses.
# 3. **Common Types of Cyberattacks**: The prevalence of phishing, ransomware, and malware as the most common types of cyberattacks suggests that businesses need to bolster their defenses against these specific threats.
# 4. **Concern Among Businesses**: The belief by 90% of companies that cybersecurity is a major concern highlights the awareness and urgency among businesses to address cybersecurity challenges.
# 5. **Average Cost of a Data Breach**: The average cost of a data breach being $3.9 million underscores the significant financial risk associated with cybersecurity failures.
#
# These insights stress the importance of robust cybersecurity measures to protect against the growing threat of cybercrime.
#
# **Topic 5: Healthcare**
#
# The data on healthcare trends indicates a substantial and growing investment in healthcare, with a focus on technology and preventive care:
#
# 1. **Global Healthcare Market**: The global healthcare market reaching $11.9 trillion by 2025 indicates a substantial and growing investment in healthcare.
# 2. **Chronic Diseases**: 75% of healthcare costs being attributed to chronic diseases suggests that preventive care and management of chronic conditions are critical areas for healthcare investment.
# 3. **Top Causes of Death**: The top causes of death being heart disease, cancer, and respiratory diseases point to areas where medical research and public health initiatives should be focused.
# 4. **Role of Technology**: The belief by 80% of doctors that technology will improve patient outcomes highlights the potential of healthcare technology to enhance care quality and efficiency.
# 5. **Common Medical Technologies**: The common use of electronic health records, telemedicine, and medical imaging as medical technologies indicates where digital transformation is happening in healthcare.
#
# These findings emphasize the importance of investing in healthcare technology and preventive care to improve patient outcomes and manage healthcare costs.
#
# **Conclusion**
#
# This comprehensive analysis of current trends and challenges across climate change, artificial intelligence, renewable energy, cybersecurity, and healthcare provides critical insights for policymakers, businesses, and individuals. The findings underscore the urgent need for action on climate change, the transformative potential of AI, the growing importance of renewable energy, the escalating threat of cybercrime, and the substantial investment in healthcare. By understanding these trends and challenges, we can work towards creating a more sustainable, secure, and healthy future for all.
#
# **Recommendations**
#
# 1. **Climate Action**: Immediate and sustained action is necessary to reduce greenhouse gas emissions and transition to renewable energy sources.
# 2. **AI Adoption**: Businesses should embrace AI to remain competitive, focusing on strategic applications and investments in key technologies.
# 3. **Renewable Energy Transition**: Continue to invest in renewable energy technologies to drive down costs and increase adoption.
# 4. **Cybersecurity Measures**: Implement robust cybersecurity measures to protect against the growing threat of cybercrime.
# 5. **Healthcare Technology**: Invest in healthcare technology and preventive care to improve patient outcomes and manage healthcare costs.
#
# By following these recommendations and leveraging the insights from this report, we can address the complex challenges facing our world today and build a more sustainable, equitable, and prosperous future for all.

# %% [markdown]
# | Feature     | Primary Goal                                  | What it Stores                                    | When It's Used                                     | How It Benefits Agents                              | Impact on LLM API Calls                     | CrewAI Parameter |
# | :---------- | :-------------------------------------------- | :------------------------------------------------ | :------------------------------------------------- | :-------------------------------------------------- | :------------------------------------------ | :--------------- |
# | **Memory** | Retain context, enable learning & adaptation  | Information, insights, learned facts, past interactions, entities | Across different tasks, or even multiple crew runs (for long-term) | Helps agents understand context, make informed decisions, build knowledge, and personalize interactions | Influences the *content* of future LLM prompts (more relevant context sent to LLM) | `memory=True`    |
# | **Caching** | Improve performance, reduce costs, prevent redundant work | Results of previous LLM calls and tool executions (exact inputs) | When an *identical* LLM call or tool execution is requested again | Speeds up execution by returning stored results instantly, avoids re-processing known inputs | Directly *reduces* redundant LLM/tool API calls, saving time and money | `cache=False` (default is True) |

# %% [markdown]
# ##  user input

# %%
from crewai import Crew, Process, Agent, Task , TaskOutput, CrewOutput

## Define Agents

researcher = Agent(
    role = "Researcher",
    goal="Conduct Foundational Research",
    backstory="An experienced researcher with an passion for uncovering insights",
    llm=llm
)

analyst = Agent(
  role='Data Analyst',
  goal='Analyze research findings',
  backstory='A meticulous analyst with a knack for uncovering patterns',
  llm=llm
)

writer = Agent(
  role='Writer',
  goal='Draft the final report',
  backstory='A skilled writer with a talent for crafting compelling narratives',
  llm=llm
)

## Defining the tasks

research_task = Task(
    agent = researcher,
    description="Gather Relevant data on topic: {topic}",
    expected_output="Raw data"
)

analysis_task = Task(
    agent=analyst, 
    description='Analyze the data of the company: {company}', 
    expected_output='Data Insights'
)
writing_task = Task(
    agent=writer,
    description='Compose the report in style: {style}',  
    expected_output='Final Report'
)

# Form the crew with a sequential process

report_crew = Crew(
    agents = [researcher,analyst,writer],
    tasks = [research_task,analysis_task,writing_task],
    process = Process.sequential  # P is capital in Process
)


user_input = {
    "topic": "generative AI",
    "company": "Google",
    "style": "In a formal tone for bullet points and informal tone for paragraphs"
}

## Execute the crew
result = report_crew.kickoff(inputs=user_input)

# %%
crew_output: CrewOutput = result.raw

# %%
print(crew_output)
# Out:
# The final report on generative AI is a comprehensive document that covers the key aspects of this rapidly evolving field. The report is written in a formal tone for bullet points and an informal tone for paragraphs, making it easy to read and understand.
#
# So, what is generative AI? Generative AI refers to a type of artificial intelligence that is capable of generating new, original content, such as images, videos, music, text, and more. This is achieved through the use of complex algorithms and neural networks that are trained on large datasets, allowing the AI to learn patterns and relationships within the data.
#
# Some of the key techniques used in generative AI include:
# * Generative Adversarial Networks (GANs): This involves training two neural networks simultaneously, one to generate new content and the other to discriminate between real and generated content.
# * Variational Autoencoders (VAEs): This involves training a neural network to learn a probabilistic representation of the input data, which can then be used to generate new content.
# * Recurrent Neural Networks (RNNs): This involves training a neural network to learn patterns in sequential data, such as text or music.
#
# These techniques have many applications, and some of the key ones include:
# * Image and video generation: Generative AI can be used to generate realistic images and videos, such as generating new faces, objects, or scenes.
# * Text generation: Generative AI can be used to generate original text, such as articles, stories, or dialogue.
# * Music generation: Generative AI can be used to generate original music, such as composing new songs or generating music in a particular style.
# * Data augmentation: Generative AI can be used to generate new training data for machine learning models, which can help to improve their performance and robustness.
#
# The benefits of generative AI are numerous, and some of the key ones include:
# * Increased creativity: Generative AI can be used to generate new and original content, which can help to stimulate creativity and innovation.
# * Improved efficiency: Generative AI can be used to automate tasks, such as data generation and content creation, which can help to improve efficiency and productivity.
# * Enhanced decision-making: Generative AI can be used to generate new scenarios and outcomes, which can help to inform decision-making and improve outcomes.
#
# However, there are also some challenges and limitations associated with generative AI, such as:
# * Quality and coherence: The quality and coherence of generated content can be variable, and may not always meet the desired standards.
# * Bias and fairness: Generative AI can perpetuate biases and unfairness if the training data is biased or unfair.
# * Intellectual property: The use of generative AI raises questions about intellectual property and ownership, particularly in cases where the generated content is highly similar to existing works.
#
# Some of the current research directions in generative AI include:
# * Multimodal generation: This involves generating content that combines multiple modalities, such as text, images, and audio.
# * Conditional generation: This involves generating content that is conditioned on specific inputs or constraints, such as generating text based on a given prompt.
# * Adversarial robustness: This involves developing generative AI models that are robust to adversarial attacks, which are designed to manipulate or deceive the model.
#
# Google is a leader in the field of generative AI, with a strong research focus on developing and applying generative AI models to various applications. Some of the key data insights for Google include:
# * Investment in Generative AI Research: Google has invested heavily in generative AI research, with a strong focus on developing new algorithms and techniques for generating high-quality content.
# * Applications of Generative AI: Google has applied generative AI to various applications, including image and video generation, text generation, and music generation.
# * Use of Generative AI in Products: Google has incorporated generative AI into various products, including Google Photos, Google Assistant, and Google Pixel phones.
#
# Google has also developed and released various datasets and tools for generative AI research, including the Google Open Images Dataset and the TensorFlow library. These resources have helped to accelerate the development of generative AI models and applications.
#
# Some key statistics and metrics for Google's generative AI efforts include:
# * Number of Research Papers: Google has published over 100 research papers on generative AI in the past year alone.
# * Number of Patents: Google has filed over 50 patents related to generative AI in the past year.
# * Investment in Generative AI Research: Google has invested over $100 million in generative AI research in the past year.
# * Number of Generative AI Models: Google has developed and released over 20 generative AI models in the past year, including models for image and video generation, text generation, and music generation.
#
# Overall, generative AI is a rapidly evolving field that has the potential to transform a wide range of industries and applications, from art and entertainment to healthcare and education. As the field of generative AI continues to evolve, Google is well-positioned to play a major role in shaping its future directions and applications.
#
# Google's notable generative AI models include:
# * Generative Adversarial Networks (GANs): Google has developed several GAN models for image and video generation, including the popular StyleGAN model.
# * Variational Autoencoders (VAEs): Google has developed several VAE models for image and video generation, including the popular VAE-GAN model.
# * Recurrent Neural Networks (RNNs): Google has developed several RNN models for text and music generation, including the popular LSTM and GRU models.
# * Transformers: Google has developed several Transformer models for text generation, including the popular BERT and T5 models.
#
# Google's notable generative AI applications include:
# * Google Photos: Google Photos uses generative AI to automatically generate photo albums and movies.
# * Google Assistant: Google Assistant uses generative AI to generate human-like responses to user queries.
# * Google Pixel phones: Google Pixel phones use generative AI to generate high-quality images and videos.
# * Google DeepDream: Google DeepDream uses generative AI to generate surreal and dreamlike images.
#
# Google's notable generative AI collaborations and partnerships include:
# * NVIDIA: Google has partnered with NVIDIA to develop specialized hardware for generative AI applications.
# * University of California, Berkeley: Google has collaborated with researchers from the University of California, Berkeley to develop new generative AI models.
# * Stanford University: Google has collaborated with researchers from Stanford University to develop new generative AI models.
# * MIT: Google has collaborated with researchers from MIT to develop new generative AI models.
#
# Some key data points for Google's generative AI efforts include:
# * Total investment in AI research: $500 million
# * Number of AI research papers published: 500
# * Number of AI-related patents filed: 1000
# * Number of AI models developed: 50
# * Number of AI applications developed: 20
# * Number of AI collaborations and partnerships: 10
# * Total revenue from AI-related products: $10 billion
# * Total number of employees working on AI: 1000
# * Total number of AI research centers: 5
# * Total number of AI conferences and workshops sponsored: 20
#
# Google's notable generative AI research papers include:
# * "Generative Adversarial Networks": This paper introduced the GAN algorithm and has been widely cited in the field of generative AI.
# * "Deep Learning": This paper introduced the concept of deep learning and has been widely cited in the field of AI research.
# * "Generative Models": This paper introduced the concept of generative models and has been widely cited in the field of generative AI.
# * "Adversarial Examples and Adversarial Training": This paper introduced the concept of adversarial examples and has been widely cited in the field of AI security.
#
# Google's notable generative AI datasets include:
# * ImageNet: This dataset is a large collection of images that is commonly used for training and evaluating image generation models.
# * CIFAR-10: This dataset is a collection of images that is commonly used for training and evaluating image generation models.
# * MNIST: This dataset is a collection of handwritten digits that is commonly used for training and evaluating image generation models.
# * WikiText: This dataset is a collection of text that is commonly used for training and evaluating text generation models.
#
# Google's notable generative AI tools and software include:
# * TensorFlow: This is a popular open-source software library for developing and deploying machine learning models, including generative AI models.
# * PyTorch: This is a popular open-source software library for developing and deploying machine learning models, including generative AI models.
# * Keras: This is a high-level software library for developing and deploying machine learning models, including generative AI models.
# * OpenCV: This is a software library for computer vision tasks, including image and video processing, that can be used in conjunction with generative AI models.
#
# Overall, Google is a leader in the field of generative AI, with a strong research focus, a wide range of applications, and a commitment to advancing the state-of-the-art in this field. As the field of generative AI continues to evolve, Google is well-positioned to play a major role in shaping its future directions and applications.

# %% [markdown]
# Best Practices for Sequential Processes
#
# Order Matters: Arrange tasks in a logical sequence where each task builds upon the previous one.
#
# Clear Task Descriptions: Provide detailed descriptions for each task to guide the agents effectively.
#
# Appropriate Agent Selection: Match agents’ skills and roles to the requirements of each task.
#
# Use Context: Leverage the context from previous tasks to inform subsequent ones.
